# %%
def test_in_a_notebook() -> None:
    assert True, "i am found as a test."

# %%
def test_notebook_in_a_notebook() -> None:
    import importnb
    with importnb.Notebook():
        import Untitled42
    assert Untitled42.function_with_a_markdown_docstring() is None
