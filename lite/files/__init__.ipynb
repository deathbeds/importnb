# %% [markdown]
# # `importnb` demos

# %% [markdown]
# this folder contains a number of interactive demos of `importnb` features.
#
# > 💡 you'll likely be viewing this in a browser, inside of a jupyterlite site.
# >
# > note there are a number of limitations to `importnb`, its dependencies, and the python
# > standard library itself when run in a browser-based kernel. these are usually called
# > out with a 💡, and likely won't trouble you with a "real" project.
# >
# > see the [lite helpers](./lite_helpers.ipynb) for some tricks.

# %% [markdown]
# ## demos
#
# - [test_notebooks.ipynb](./test_notebooks.ipynb) shows how to use `importnb` in tests
