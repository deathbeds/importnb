# %% [markdown]
# # `importnb` demos

# %% [markdown]
# this folder contains a number of interactive demos of `importnb` features.
#
# > 😈 there are still some things `importnb` can't do. we call these out with a 😈
#
# > 💡 you'll likely be viewing this in a browser, inside of a jupyterlite site.
# >
# > note there are a number of limitations to `importnb`, its dependencies, and the python
# > standard library itself when run in a browser-based kernel. these are usually called
# > out with a 💡, and likely won't trouble you with a "real" project.
# >
# > see the [lite helpers](./lite_helpers.ipynb) for some tricks.

# %% [markdown]
# ## demos
#
# - [docs_notebooks.ipynb](/lite/notebooks/index.html?path=docs_notebooks.ipynb)
#   - get notebook API documentation with tools like `sphinx`
# - [test_notebooks.ipynb](/lite/notebooks/index.html?path=test_notebooks.ipynb)
#   - test notebooks (and run tests with notebooks) with `pytest`, and `coverage`
# - [widget_notebooks.ipynb](/lite/notebooks/index.html?path=widget_notebooks.ipynb)
#   - separate the "plumbing" and "porcelain" of a [Jupyter Widget](https://ipywidgets.readthedocs.io/en/latest/)-based application
#
# [view all the demo content](/lite/tree/index.html)
