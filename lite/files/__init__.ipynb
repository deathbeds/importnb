# %% [markdown]
# # `importnb` demo

# %% [markdown]
# this folder contains a number of interactive demos of `importnb` features.
#
# likely, you'll be viewing this in a browser, inside of a JupyterLite site. note
# there are a number of limitations to `importnb`, its dependencies, and the python
# standard library itself when run in a browser-based kernel.

# %%
import importnb

importnb.__version__
