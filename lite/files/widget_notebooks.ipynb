# %% [markdown]
# # widget notebooks
#
# > importnb makes it easier to show a widget-based demo "above the fold" by separating the [underlying code](/lite/notebooks/index.html?path=widget_notebooks_plumbing.ipynb) from the narrative

# %%
# 💡 in lite we need all imports ready
# %pip install -q ipywidgets

# %%
with __import__("importnb").Notebook():
    display(__import__("widget_notebooks_plumbing").app)
