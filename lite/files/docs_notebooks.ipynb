# %% [markdown]
# docs notebooks
# ==============

# %% [markdown]
# notebooks fulfill a specific, narrative form of interactive documentation.
#
# often missing when integrating notebooks into a documentation suite are static API documentation, with which `importnb` can help.

# %% [markdown]
# ## write docs

# %% [markdown]
# ## A Demo Class
#
# because `DemoClass` provides a docstring (conventionally, in `.rst`), this markdown cell will not be used.

# %%
from dataclasses import dataclass


@dataclass
class DemoClass:
    """this is the documentation for the class, written in ``.rst``."""

    #: members can have above-line docs, can use simple ``.rst``
    foo: int

    bar: str = "bar"
    """members can use a multi-line `.rst` docstring...
    
    * subsequent lines are omitted, by default    
    """

    def baz() -> bool:
        """Method members generally use the multiline pattern.

        Code blocks `will` be expanded here:

        ..code:

            DemoClass().baz()

        """
        return True

# %% [markdown]
# ## build docs

# %% [markdown]
# this build uses `sphinx`, which can make a single html file from any number of source documents, usually `.rst`. `myst-parser` expands this to include `.md` files.
#
# > 💡 `mystnb` would offer even more integration with notebooks, but has unresolveable dependencies in jupyterlite

# %%
if __name__ == "__main__":
    # %pip install myst-parser sphinx-autodoc-typehints
    import tempfile

    from sphinx.cmd.build import build_main

    import importnb

    with importnb.Notebook(), tempfile.TemporaryDirectory() as td:
        from lite_helpers import sphinx_html

        build_main(["-qEb", "singlehtml", ".", f"{td}/html"])
        sphinx_html(f"{td}/html")
